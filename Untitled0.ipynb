# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

import pickle

# %%
data = pd.read_csv("/content/drive/My Drive/PAD/Project/dataset.csv")
data.columns
# Out:
# Index(['Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker',
#        'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education',
#        'Income'],
#       dtype='object')

# %%
for i in data.columns:
  print(i + ": min - " + str(data[i].min()) + ", max - " + str(data[i].max()))
# Out:
# Diabetes_binary: min - 0.0, max - 1.0
# HighBP: min - 0.0, max - 1.0
# HighChol: min - 0.0, max - 1.0
# CholCheck: min - 0.0, max - 1.0
# BMI: min - 12.0, max - 98.0
# Smoker: min - 0.0, max - 1.0
# Stroke: min - 0.0, max - 1.0
# HeartDiseaseorAttack: min - 0.0, max - 1.0
# PhysActivity: min - 0.0, max - 1.0
# Fruits: min - 0.0, max - 1.0
# Veggies: min - 0.0, max - 1.0
# HvyAlcoholConsump: min - 0.0, max - 1.0
# AnyHealthcare: min - 0.0, max - 1.0
# NoDocbcCost: min - 0.0, max - 1.0
# GenHlth: min - 1.0, max - 5.0
# MentHlth: min - 0.0, max - 30.0
# PhysHlth: min - 0.0, max - 30.0
# DiffWalk: min - 0.0, max - 1.0
# Sex: min - 0.0, max - 1.0
# Age: min - 1.0, max - 13.0
# Education: min - 1.0, max - 6.0
# Income: min - 1.0, max - 8.0

# %%
y = data.iloc[:, 0]
x = data.iloc[:, 1:]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
def model(X_train, y_train):
    
    forest = RandomForestClassifier (n_estimators=20, random_state=0)
    forest.fit(X_train,y_train)
    print("Random Forest: {0}".format(forest.score(X_train,y_train)))
   
    tree = DecisionTreeClassifier()
    tree.fit(X_train,y_train)
    print("Decision Tree: {0}".format(tree.score(X_train,y_train)))

    return forest, tree

forest, tree = model(X_train,y_train)
# Out:
# Random Forest: 0.9899381110059918
# Decision Tree: 0.9943777593818984

# %%
y1_predict = forest.predict(X_test)
print("Random Forest {0}".format(accuracy_score(y_test, y1_predict)))

y3_predict = tree.predict(X_test)
print("Decision Tree {0}".format(accuracy_score(y_test, y3_predict)))
# Out:
# Random Forest 0.8552704194260485
# Decision Tree 0.7958845789971618

# %%
pickle.dump(tree, open("model.sv",'wb'))
